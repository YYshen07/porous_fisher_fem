# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy.optimize import curve_fit

# %%
BASE_DIR = '/Users/yanyu/Desktop/课题组文章/金晓强老师/AS审稿意见/20251102代码'
summary_path = os.path.join(BASE_DIR, 'sensitive_analysis', 'sensitive_analysis_summary.csv')
summary_df = pd.read_csv(summary_path)
max_steps = 60000
summary_df.head()
# Out:
#    Lx  Ly   afr  threshold  fifty_step  full_step  step_minus20  step_plus20  \
# 0  40  40  0.10       0.65         817       2358           797          837
# 1  40  40  0.10       0.80        1509       3223          1489         1529
# 2  40  40  0.10       0.95        3618       5360          3598         3638
# 3  40  40  0.25       0.65         327        944           307          347
# 4  40  40  0.25       0.80         604       1289           584          624
#
#    step_minus_2pct_full  step_plus_2pct_full
# 0                   770                  864
# 1                  1445                 1573
# 2                  3511                 3725
# 3                   309                  345
# 4                   579                  629

# %%
def power_law(x, a, b):
    return a * np.power(np.abs(x), b)


def exp_func(x, a, b):
    return a * np.exp(b * x)

# %%
def format_afr(value: float) -> str:
    txt = f"{value:.2f}"
    txt = txt.rstrip('0').rstrip('.')
    return txt


def format_threshold(value: float) -> str:
    txt = f"{value:.2f}"
    txt = txt.rstrip('0').rstrip('.')
    return txt


def build_filename(Lx: int, Ly: int, afr: float, threshold: float, step: int) -> str:
    afr_str = format_afr(afr)
    threshold_str = format_threshold(threshold)
    return f"Lx{Lx}_Ly{Ly}_afr{afr_str}_thr{threshold_str}_flag1_timestep{step}.csv"


def load_interface_csv(Lx: int, Ly: int, afr: float, threshold: float, step: int):
    filename = build_filename(Lx, Ly, afr, threshold, step)
    path = os.path.join(BASE_DIR, 'sensitive_analysis', filename)
    if not os.path.exists(path):
        return None
    data = pd.read_csv(path)
    expected_cols = {'x', 'y', 'angle', 'curvature'}
    if not expected_cols.issubset(data.columns):
        raise ValueError(f"文件 {filename} 缺少必要列 {expected_cols}")
    return data.sort_values('angle').reset_index(drop=True)


def collect_pair_data(first_df: pd.DataFrame, second_df: pd.DataFrame):
    if first_df is None or second_df is None:
        return None
    if len(first_df) != len(second_df):
        return None
    if not np.allclose(first_df['angle'].values, second_df['angle'].values):
        return None

    dx = second_df['x'].values - first_df['x'].values
    dy = second_df['y'].values - first_df['y'].values
    distances = np.sqrt(dx * dx + dy * dy)
    return {
        'angles': first_df['angle'].values,
        'curvatures1': first_df['curvature'].values,
        'curvatures2': second_df['curvature'].values,
        'distances': distances,
        'x1': first_df['x'].values,
        'y1': first_df['y'].values,
        'x2': second_df['x'].values,
        'y2': second_df['y'].values
    }

# %%
def analyze_pair(Lx, Ly, afr, threshold, step1, step2, pair_data, output_dir, pair_label):
    angles = pair_data['angles']
    curvatures1 = pair_data['curvatures1']
    curvatures2 = pair_data['curvatures2']
    distances = pair_data['distances']
    x1, y1 = pair_data['x1'], pair_data['y1']
    x2, y2 = pair_data['x2'], pair_data['y2']

    # 相关系数基于前一时间步的曲率
    pearson_r, pearson_p = stats.pearsonr(curvatures1, distances)
    spearman_r, spearman_p = stats.spearmanr(curvatures1, distances)

    # 多项式拟合
    poly1_coefs = np.polyfit(curvatures1, distances, 1)
    poly1_func = np.poly1d(poly1_coefs)

    poly2_coefs = np.polyfit(curvatures1, distances, 2)
    poly2_func = np.poly1d(poly2_coefs)

    poly3_coefs = np.polyfit(curvatures1, distances, 3)
    poly3_func = np.poly1d(poly3_coefs)

    # 幂律拟合
    power_fit_valid = False
    try:
        valid_idx = curvatures1 > 0
        if np.sum(valid_idx) > 2:
            a_power, b_power = curve_fit(power_law, curvatures1[valid_idx], distances[valid_idx], maxfev=10000)[0]
            power_fit_valid = True
        else:
            a_power = b_power = None
    except Exception:
        a_power = b_power = None

    # 指数拟合
    exp_fit_valid = False
    try:
        a_exp, b_exp = curve_fit(exp_func, curvatures1, distances, maxfev=10000)[0]
        exp_fit_valid = True
    except Exception:
        a_exp = b_exp = None

    # 绘图：左边界面，右侧拟合
    fig, (ax_left, ax_right) = plt.subplots(1, 2, figsize=(14, 5))

    sc1 = ax_left.scatter(x1, y1, c=curvatures1, cmap='jet', s=20, label=f'Step {step1}')
    ax_left.plot(x1, y1, 'b-', alpha=0.4)
    sc2 = ax_left.scatter(x2, y2, c=curvatures2, cmap='jet', s=20, marker='s', label=f'Step {step2}')
    ax_left.plot(x2, y2, 'r-', alpha=0.4)
    ax_left.set_xlim(Lx / 2 - 1, Lx)
    ax_left.set_ylim(Ly / 2 - 1, Ly)
    ax_left.set_aspect('equal')
    ax_left.grid(True)
    ax_left.plot(Lx / 2, Ly / 2, 'ko', markersize=4)
    ax_left.axhline(y=Ly / 2, color='gray', linestyle='--', alpha=0.3)
    ax_left.axvline(x=Lx / 2, color='gray', linestyle='--', alpha=0.3)
    cbar = fig.colorbar(sc1, ax=ax_left)
    cbar.set_label('Curvature')
    ax_left.legend(loc='lower left')
    ax_left.set_title(f'Interface ({step1} → {step2})')

    ax_right.scatter(curvatures1, distances, alpha=0.5, s=12, label='Data points')
    x_range = np.linspace(curvatures1.min(), curvatures1.max(), 200)
    ax_right.plot(x_range, poly1_func(x_range), 'r-', linewidth=2, label='Linear')
    ax_right.plot(x_range, poly2_func(x_range), 'g-', linewidth=2, label='Quadratic')
    ax_right.plot(x_range, poly3_func(x_range), 'b-', linewidth=2, label='Cubic')

    if power_fit_valid:
        ax_right.plot(x_range, power_law(x_range, a_power, b_power), 'm-', linewidth=2, label='Power')
    if exp_fit_valid:
        ax_right.plot(x_range, exp_func(x_range, a_exp, b_exp), 'c-', linewidth=2, label='Exp')

    text_info = (f"Pearson r: {pearson_r:.4f} (p={pearson_p:.4f})\n"
                 f"Spearman r: {spearman_r:.4f} (p={spearman_p:.4f})")
    ax_right.text(0.05, 0.95, text_info, transform=ax_right.transAxes, fontsize=11,
                  verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))
    ax_right.grid(True)
    ax_right.set_xlabel('Curvature')
    ax_right.set_ylabel('Distance')
    ax_right.legend(loc='lower right')
    ax_right.set_title('Curvature vs. Distance')

    plt.tight_layout()

    afr_str = format_afr(afr)
    threshold_str = format_threshold(threshold)
    output_name = f"Lx{Lx}_Ly{Ly}_afr{afr_str}_thr{threshold_str}_flag1_timestep{step1}_{step2}.png"
    output_path = os.path.join(output_dir, output_name)
    plt.savefig(output_path, dpi=300)
    plt.close(fig)

    return {
        'Lx': Lx,
        'Ly': Ly,
        'afr': afr,
        'threshold': threshold,
        'pair_type': pair_label,
        'step_start': step1,
        'step_end': step2,
        'points': len(curvatures1),
        'pearson_r': pearson_r,
        'pearson_p': pearson_p,
        'spearman_r': spearman_r,
        'spearman_p': spearman_p
    }

# %%
output_dir = os.path.join(BASE_DIR, 'sensitive_analysis')
results = []

for _, row in summary_df.iterrows():
    Lx = int(row['Lx'])
    Ly = int(row['Ly'])
    afr = float(row['afr'])
    threshold = float(row['threshold'])
    fifty_step = row['fifty_step']

    if pd.isna(fifty_step):
        print(f"跳过 Lx={Lx}, afr={afr}, threshold={threshold}：缺少 50% 步长")
        continue

    fifty_step = int(fifty_step)
    
    # 从 summary CSV 中读取实际的步长值
    step_minus20 = row.get('step_minus20', np.nan)
    step_plus20 = row.get('step_plus20', np.nan)
    step_minus_2pct = row.get('step_minus_2pct_full', np.nan)
    step_plus_2pct = row.get('step_plus_2pct_full', np.nan)
    
    step_info = [
        ('minus20', step_minus20, fifty_step),
        ('plus20', fifty_step, step_plus20),
        ('minus_2pct_full', step_minus_2pct, fifty_step),
        ('plus_2pct_full', fifty_step, step_plus_2pct)
    ]

    data_cache = {}

    for pair_label, start_step, end_step in step_info:
        if pd.isna(start_step) or pd.isna(end_step):
            continue
        start_step = int(start_step)
        end_step = int(end_step)

        if start_step < 1 or end_step < 1 or end_step > max_steps:
            continue

        if start_step not in data_cache:
            data_cache[start_step] = load_interface_csv(Lx, Ly, afr, threshold, start_step)
        if end_step not in data_cache:
            data_cache[end_step] = load_interface_csv(Lx, Ly, afr, threshold, end_step)

        data_start = data_cache[start_step]
        data_end = data_cache[end_step]

        pair_data = collect_pair_data(data_start, data_end)
        if pair_data is None:
            print(f"警告: Lx={Lx}, afr={afr}, threshold={threshold} 缺少 {start_step}->{end_step} 数据")
            continue

        result_pair = analyze_pair(Lx, Ly, afr, threshold, start_step, end_step, pair_data, output_dir, pair_label)
        results.append(result_pair)
        print(f"Lx={Lx}, afr={afr}, threshold={threshold}, type={pair_label}, steps {start_step}->{end_step}")
        print(f"  数据点: {result_pair['points']}")
        print(f"  Pearson correlation: r = {result_pair['pearson_r']:.6f}, p = {result_pair['pearson_p']:.6f}")
        print(f"  Spearman correlation: r = {result_pair['spearman_r']:.6f}, p = {result_pair['spearman_p']:.6f}\n")

results_df = pd.DataFrame(results)
results_df
# Out:
# Lx=40, afr=0.1, threshold=0.65, type=minus20, steps 797->817
#   数据点: 91
#   Pearson correlation: r = 0.954162, p = 0.000000
#   Spearman correlation: r = 0.979419, p = 0.000000
#
# Lx=40, afr=0.1, threshold=0.65, type=plus20, steps 817->837
#   数据点: 91
#   Pearson correlation: r = 0.967447, p = 0.000000
#   Spearman correlation: r = 0.982513, p = 0.000000
#
# Lx=40, afr=0.1, threshold=0.65, type=minus_2pct_full, steps 770->817
#   数据点: 91
#   Pearson correlation: r = 0.980067, p = 0.000000
#   Spearman correlation: r = 0.995237, p = 0.000000
#
# Lx=40, afr=0.1, threshold=0.65, type=plus_2pct_full, steps 817->864
#   数据点: 91
#   Pearson correlation: r = 0.982069, p = 0.000000
#   Spearman correlation: r = 0.996898, p = 0.000000
#
# Lx=40, afr=0.1, threshold=0.8, type=minus20, steps 1489->1509
#   数据点: 91
#   Pearson correlation: r = 0.898512, p = 0.000000
#   Spearman correlation: r = 0.953639, p = 0.000000
#
# Lx=40, afr=0.1, threshold=0.8, type=plus20, steps 1509->1529
#   数据点: 91
#   Pearson correlation: r = 0.951413, p = 0.000000
#   Spearman correlation: r = 0.970351, p = 0.000000
#
# Lx=40, afr=0.1, threshold=0.8, type=minus_2pct_full, steps 1445->1509
#   数据点: 91
#   Pearson correlation: r = 0.982357, p = 0.000000
#   Spearman correlation: r = 0.994863, p = 0.000000
#
# Lx=40, afr=0.1, threshold=0.8, type=plus_2pct_full, steps 1509->1573
#   数据点: 91
#   Pearson correlation: r = 0.982190, p = 0.000000
#   Spearman correlation: r = 0.994938, p = 0.000000
#
# Lx=40, afr=0.1, threshold=0.95, type=minus20, steps 3598->3618
#   数据点: 91
#   Pearson correlation: r = 0.906233, p = 0.000000
#   Spearman correlation: r = 0.947783, p = 0.000000
#
# Lx=40, afr=0.1, threshold=0.95, type=plus20, steps 3618->3638
#   数据点: 91
#   Pearson correlation: r = 0.916928, p = 0.000000
#   Spearman correlation: r = 0.939638, p = 0.000000
#
# Lx=40, afr=0.1, threshold=0.95, type=minus_2pct_full, steps 3511->3618
#   数据点: 91
#   Pearson correlation: r = 0.983718, p = 0.000000
#   Spearman correlation: r = 0.996408, p = 0.000000
#
# Lx=40, afr=0.1, threshold=0.95, type=plus_2pct_full, steps 3618->3725
#   数据点: 91
#   Pearson correlation: r = 0.982866, p = 0.000000
#   Spearman correlation: r = 0.996078, p = 0.000000
#
# Lx=40, afr=0.25, threshold=0.65, type=minus20, steps 307->327
#   数据点: 91
#   Pearson correlation: r = 0.980115, p = 0.000000
#   Spearman correlation: r = 0.996097, p = 0.000000
#
# Lx=40, afr=0.25, threshold=0.65, type=plus20, steps 327->347
#   数据点: 91
#   Pearson correlation: r = 0.982767, p = 0.000000
#   Spearman correlation: r = 0.997642, p = 0.000000
#
# Lx=40, afr=0.25, threshold=0.65, type=minus_2pct_full, steps 309->327
#   数据点: 91
#   Pearson correlation: r = 0.979705, p = 0.000000
#   Spearman correlation: r = 0.994707, p = 0.000000
#
# Lx=40, afr=0.25, threshold=0.65, type=plus_2pct_full, steps 327->345
#   数据点: 91
#   Pearson correlation: r = 0.981969, p = 0.000000
#   Spearman correlation: r = 0.997145, p = 0.000000
#
# Lx=40, afr=0.25, threshold=0.8, type=minus20, steps 584->604
#   数据点: 91
#   Pearson correlation: r = 0.980790, p = 0.000000
#   Spearman correlation: r = 0.994130, p = 0.000000
#
# Lx=40, afr=0.25, threshold=0.8, type=plus20, steps 604->624
#   数据点: 91
#   Pearson correlation: r = 0.975134, p = 0.000000
#   Spearman correlation: r = 0.992004, p = 0.000000
#
# Lx=40, afr=0.25, threshold=0.8, type=minus_2pct_full, steps 579->604
#   数据点: 91
#   Pearson correlation: r = 0.983305, p = 0.000000
#   Spearman correlation: r = 0.994524, p = 0.000000
#
# Lx=40, afr=0.25, threshold=0.8, type=plus_2pct_full, steps 604->629
#   数据点: 91
#   Pearson correlation: r = 0.981380, p = 0.000000
#   Spearman correlation: r = 0.993154, p = 0.000000
#
# Lx=40, afr=0.25, threshold=0.95, type=minus20, steps 1428->1448
#   数据点: 91
#   Pearson correlation: r = 0.978705, p = 0.000000
#   Spearman correlation: r = 0.991020, p = 0.000000
#
# Lx=40, afr=0.25, threshold=0.95, type=plus20, steps 1448->1468
#   数据点: 91
#   Pearson correlation: r = 0.975565, p = 0.000000
#   Spearman correlation: r = 0.989886, p = 0.000000
#
# Lx=40, afr=0.25, threshold=0.95, type=minus_2pct_full, steps 1406->1448
#   数据点: 91
#   Pearson correlation: r = 0.983759, p = 0.000000
#   Spearman correlation: r = 0.996281, p = 0.000000
#
# Lx=40, afr=0.25, threshold=0.95, type=plus_2pct_full, steps 1448->1490
#   数据点: 91
#   Pearson correlation: r = 0.981828, p = 0.000000
#   Spearman correlation: r = 0.995807, p = 0.000000
#
# Lx=40, afr=0.4, threshold=0.65, type=minus20, steps 185->205
#   数据点: 91
#   Pearson correlation: r = 0.980394, p = 0.000000
#   Spearman correlation: r = 0.995878, p = 0.000000
#
# Lx=40, afr=0.4, threshold=0.65, type=plus20, steps 205->225
#   数据点: 91
#   Pearson correlation: r = 0.981640, p = 0.000000
#   Spearman correlation: r = 0.996420, p = 0.000000
#
# Lx=40, afr=0.4, threshold=0.65, type=minus_2pct_full, steps 194->205
#   数据点: 91
#   Pearson correlation: r = 0.980689, p = 0.000000
#   Spearman correlation: r = 0.995767, p = 0.000000
#
# Lx=40, afr=0.4, threshold=0.65, type=plus_2pct_full, steps 205->216
#   数据点: 91
#   Pearson correlation: r = 0.980461, p = 0.000000
#   Spearman correlation: r = 0.994751, p = 0.000000
#
# Lx=40, afr=0.4, threshold=0.8, type=minus20, steps 358->378
#   数据点: 91
#   Pearson correlation: r = 0.983940, p = 0.000000
#   Spearman correlation: r = 0.995608, p = 0.000000
#
# Lx=40, afr=0.4, threshold=0.8, type=plus20, steps 378->398
#   数据点: 91
#   Pearson correlation: r = 0.983534, p = 0.000000
#   Spearman correlation: r = 0.997001, p = 0.000000
#
# Lx=40, afr=0.4, threshold=0.8, type=minus_2pct_full, steps 362->378
#   数据点: 91
#   Pearson correlation: r = 0.984096, p = 0.000000
#   Spearman correlation: r = 0.995114, p = 0.000000
#
# Lx=40, afr=0.4, threshold=0.8, type=plus_2pct_full, steps 378->394
#   数据点: 91
#   Pearson correlation: r = 0.981858, p = 0.000000
#   Spearman correlation: r = 0.995982, p = 0.000000
#
# Lx=40, afr=0.4, threshold=0.95, type=minus20, steps 885->905
#   数据点: 91
#   Pearson correlation: r = 0.983986, p = 0.000000
#   Spearman correlation: r = 0.995779, p = 0.000000
#
# Lx=40, afr=0.4, threshold=0.95, type=plus20, steps 905->925
#   数据点: 91
#   Pearson correlation: r = 0.982970, p = 0.000000
#   Spearman correlation: r = 0.996117, p = 0.000000
#
# Lx=40, afr=0.4, threshold=0.95, type=minus_2pct_full, steps 879->905
#   数据点: 91
#   Pearson correlation: r = 0.983202, p = 0.000000
#   Spearman correlation: r = 0.997093, p = 0.000000
#
# Lx=40, afr=0.4, threshold=0.95, type=plus_2pct_full, steps 905->931
#   数据点: 91
#   Pearson correlation: r = 0.981942, p = 0.000000
#   Spearman correlation: r = 0.996110, p = 0.000000
#
# Lx=60, afr=0.1, threshold=0.65, type=minus20, steps 1905->1925
#   数据点: 91
#   Pearson correlation: r = 0.862970, p = 0.000000
#   Spearman correlation: r = 0.945910, p = 0.000000
#
# Lx=60, afr=0.1, threshold=0.65, type=plus20, steps 1925->1945
#   数据点: 91
#   Pearson correlation: r = 0.813413, p = 0.000000
#   Spearman correlation: r = 0.864243, p = 0.000000
#
# Lx=60, afr=0.1, threshold=0.65, type=minus_2pct_full, steps 1818->1925
#   数据点: 91
#   Pearson correlation: r = 0.981580, p = 0.000000
#   Spearman correlation: r = 0.996535, p = 0.000000
#
# Lx=60, afr=0.1, threshold=0.65, type=plus_2pct_full, steps 1925->2032
#   数据点: 91
#   Pearson correlation: r = 0.983465, p = 0.000000
#   Spearman correlation: r = 0.997957, p = 0.000000
#
# Lx=60, afr=0.1, threshold=0.8, type=minus20, steps 3657->3677
#   数据点: 91
#   Pearson correlation: r = 0.841177, p = 0.000000
#   Spearman correlation: r = 0.918689, p = 0.000000
#
# Lx=60, afr=0.1, threshold=0.8, type=plus20, steps 3677->3697
#   数据点: 91
#   Pearson correlation: r = 0.721539, p = 0.000000
#   Spearman correlation: r = 0.805617, p = 0.000000
#
# Lx=60, afr=0.1, threshold=0.8, type=minus_2pct_full, steps 3530->3677
#   数据点: 91
#   Pearson correlation: r = 0.984829, p = 0.000000
#   Spearman correlation: r = 0.998933, p = 0.000000
#
# Lx=60, afr=0.1, threshold=0.8, type=plus_2pct_full, steps 3677->3824
#   数据点: 91
#   Pearson correlation: r = 0.984520, p = 0.000000
#   Spearman correlation: r = 0.993298, p = 0.000000
#
# Lx=60, afr=0.1, threshold=0.95, type=minus20, steps 8491->8511
#   数据点: 91
#   Pearson correlation: r = 0.807015, p = 0.000000
#   Spearman correlation: r = 0.848831, p = 0.000000
#
# Lx=60, afr=0.1, threshold=0.95, type=plus20, steps 8511->8531
#   数据点: 91
#   Pearson correlation: r = 0.800780, p = 0.000000
#   Spearman correlation: r = 0.823872, p = 0.000000
#
# Lx=60, afr=0.1, threshold=0.95, type=minus_2pct_full, steps 8266->8511
#   数据点: 91
#   Pearson correlation: r = 0.983869, p = 0.000000
#   Spearman correlation: r = 0.999614, p = 0.000000
#
# Lx=60, afr=0.1, threshold=0.95, type=plus_2pct_full, steps 8511->8756
#   数据点: 91
#   Pearson correlation: r = 0.986424, p = 0.000000
#   Spearman correlation: r = 0.998256, p = 0.000000
#
# Lx=60, afr=0.25, threshold=0.65, type=minus20, steps 751->771
#   数据点: 91
#   Pearson correlation: r = 0.970117, p = 0.000000
#   Spearman correlation: r = 0.980275, p = 0.000000
#
# Lx=60, afr=0.25, threshold=0.65, type=plus20, steps 771->791
#   数据点: 91
#   Pearson correlation: r = 0.980462, p = 0.000000
#   Spearman correlation: r = 0.983301, p = 0.000000
#
# Lx=60, afr=0.25, threshold=0.65, type=minus_2pct_full, steps 728->771
#   数据点: 91
#   Pearson correlation: r = 0.981664, p = 0.000000
#   Spearman correlation: r = 0.996380, p = 0.000000
#
# Lx=60, afr=0.25, threshold=0.65, type=plus_2pct_full, steps 771->814
#   数据点: 91
#   Pearson correlation: r = 0.985052, p = 0.000000
#   Spearman correlation: r = 0.997654, p = 0.000000
#
# Lx=60, afr=0.25, threshold=0.8, type=minus20, steps 1451->1471
#   数据点: 91
#   Pearson correlation: r = 0.966145, p = 0.000000
#   Spearman correlation: r = 0.978639, p = 0.000000
#
# Lx=60, afr=0.25, threshold=0.8, type=plus20, steps 1471->1491
#   数据点: 91
#   Pearson correlation: r = 0.956885, p = 0.000000
#   Spearman correlation: r = 0.973374, p = 0.000000
#
# Lx=60, afr=0.25, threshold=0.8, type=minus_2pct_full, steps 1412->1471
#   数据点: 91
#   Pearson correlation: r = 0.983728, p = 0.000000
#   Spearman correlation: r = 0.998941, p = 0.000000
#
# Lx=60, afr=0.25, threshold=0.8, type=plus_2pct_full, steps 1471->1530
#   数据点: 91
#   Pearson correlation: r = 0.984532, p = 0.000000
#   Spearman correlation: r = 0.993453, p = 0.000000
#
# Lx=60, afr=0.25, threshold=0.95, type=minus20, steps 3384->3404
#   数据点: 91
#   Pearson correlation: r = 0.892488, p = 0.000000
#   Spearman correlation: r = 0.930684, p = 0.000000
#
# Lx=60, afr=0.25, threshold=0.95, type=plus20, steps 3404->3424
#   数据点: 91
#   Pearson correlation: r = 0.957309, p = 0.000000
#   Spearman correlation: r = 0.960646, p = 0.000000
#
# Lx=60, afr=0.25, threshold=0.95, type=minus_2pct_full, steps 3306->3404
#   数据点: 91
#   Pearson correlation: r = 0.983760, p = 0.000000
#   Spearman correlation: r = 0.999387, p = 0.000000
#
# Lx=60, afr=0.25, threshold=0.95, type=plus_2pct_full, steps 3404->3502
#   数据点: 91
#   Pearson correlation: r = 0.986661, p = 0.000000
#   Spearman correlation: r = 0.997268, p = 0.000000
#
# Lx=60, afr=0.4, threshold=0.65, type=minus20, steps 462->482
#   数据点: 91
#   Pearson correlation: r = 0.982353, p = 0.000000
#   Spearman correlation: r = 0.994465, p = 0.000000
#
# Lx=60, afr=0.4, threshold=0.65, type=plus20, steps 482->502
#   数据点: 91
#   Pearson correlation: r = 0.966889, p = 0.000000
#   Spearman correlation: r = 0.994915, p = 0.000000
#
# Lx=60, afr=0.4, threshold=0.65, type=minus_2pct_full, steps 455->482
#   数据点: 91
#   Pearson correlation: r = 0.981959, p = 0.000000
#   Spearman correlation: r = 0.996404, p = 0.000000
#
# Lx=60, afr=0.4, threshold=0.65, type=plus_2pct_full, steps 482->509
#   数据点: 91
#   Pearson correlation: r = 0.984703, p = 0.000000
#   Spearman correlation: r = 0.997854, p = 0.000000
#
# Lx=60, afr=0.4, threshold=0.8, type=minus20, steps 900->920
#   数据点: 91
#   Pearson correlation: r = 0.957307, p = 0.000000
#   Spearman correlation: r = 0.991442, p = 0.000000
#
# Lx=60, afr=0.4, threshold=0.8, type=plus20, steps 920->940
#   数据点: 91
#   Pearson correlation: r = 0.976306, p = 0.000000
#   Spearman correlation: r = 0.990936, p = 0.000000
#
# Lx=60, afr=0.4, threshold=0.8, type=minus_2pct_full, steps 884->920
#   数据点: 91
#   Pearson correlation: r = 0.982497, p = 0.000000
#   Spearman correlation: r = 0.998276, p = 0.000000
#
# Lx=60, afr=0.4, threshold=0.8, type=plus_2pct_full, steps 920->956
#   数据点: 91
#   Pearson correlation: r = 0.983533, p = 0.000000
#   Spearman correlation: r = 0.993605, p = 0.000000
#
# Lx=60, afr=0.4, threshold=0.95, type=minus20, steps 2108->2128
#   数据点: 91
#   Pearson correlation: r = 0.946805, p = 0.000000
#   Spearman correlation: r = 0.995003, p = 0.000000
#
# Lx=60, afr=0.4, threshold=0.95, type=plus20, steps 2128->2148
#   数据点: 91
#   Pearson correlation: r = 0.977898, p = 0.000000
#   Spearman correlation: r = 0.988042, p = 0.000000
#
# Lx=60, afr=0.4, threshold=0.95, type=minus_2pct_full, steps 2067->2128
#   数据点: 91
#   Pearson correlation: r = 0.984281, p = 0.000000
#   Spearman correlation: r = 0.999518, p = 0.000000
#
# Lx=60, afr=0.4, threshold=0.95, type=plus_2pct_full, steps 2128->2189
#   数据点: 91
#   Pearson correlation: r = 0.985777, p = 0.000000
#   Spearman correlation: r = 0.998682, p = 0.000000
#
# Lx=80, afr=0.1, threshold=0.65, type=minus20, steps 3480->3500
#   数据点: 91
#   Pearson correlation: r = 0.695604, p = 0.000000
#   Spearman correlation: r = 0.878655, p = 0.000000
#
# Lx=80, afr=0.1, threshold=0.65, type=plus20, steps 3500->3520
#   数据点: 91
#   Pearson correlation: r = 0.504203, p = 0.000000
#   Spearman correlation: r = 0.719428, p = 0.000000
#
# Lx=80, afr=0.1, threshold=0.65, type=minus_2pct_full, steps 3307->3500
#   数据点: 91
#   Pearson correlation: r = 0.980090, p = 0.000000
#   Spearman correlation: r = 0.996961, p = 0.000000
#
# Lx=80, afr=0.1, threshold=0.65, type=plus_2pct_full, steps 3500->3693
#   数据点: 91
#   Pearson correlation: r = 0.982916, p = 0.000000
#   Spearman correlation: r = 0.994767, p = 0.000000
#
# Lx=80, afr=0.1, threshold=0.8, type=minus20, steps 6597->6617
#   数据点: 91
#   Pearson correlation: r = 0.364207, p = 0.000387
#   Spearman correlation: r = 0.847888, p = 0.000000
#
# Lx=80, afr=0.1, threshold=0.8, type=plus20, steps 6617->6637
#   数据点: 91
#   Pearson correlation: r = 0.415343, p = 0.000042
#   Spearman correlation: r = 0.785205, p = 0.000000
#
# Lx=80, afr=0.1, threshold=0.8, type=minus_2pct_full, steps 6353->6617
#   数据点: 91
#   Pearson correlation: r = 0.980453, p = 0.000000
#   Spearman correlation: r = 0.995106, p = 0.000000
#
# Lx=80, afr=0.1, threshold=0.8, type=plus_2pct_full, steps 6617->6881
#   数据点: 91
#   Pearson correlation: r = 0.984686, p = 0.000000
#   Spearman correlation: r = 0.998308, p = 0.000000
#
# Lx=80, afr=0.1, threshold=0.95, type=minus20, steps 15285->15305
#   数据点: 91
#   Pearson correlation: r = 0.290205, p = 0.005264
#   Spearman correlation: r = 0.713988, p = 0.000000
#
# Lx=80, afr=0.1, threshold=0.95, type=plus20, steps 15305->15325
#   数据点: 91
#   Pearson correlation: r = 0.234006, p = 0.025582
#   Spearman correlation: r = 0.646414, p = 0.000000
#
# Lx=80, afr=0.1, threshold=0.95, type=minus_2pct_full, steps 14866->15305
#   数据点: 91
#   Pearson correlation: r = 0.982827, p = 0.000000
#   Spearman correlation: r = 0.998539, p = 0.000000
#
# Lx=80, afr=0.1, threshold=0.95, type=plus_2pct_full, steps 15305->15744
#   数据点: 91
#   Pearson correlation: r = 0.985704, p = 0.000000
#   Spearman correlation: r = 0.998264, p = 0.000000
#
# Lx=80, afr=0.25, threshold=0.65, type=minus20, steps 1381->1401
#   数据点: 91
#   Pearson correlation: r = 0.910490, p = 0.000000
#   Spearman correlation: r = 0.970012, p = 0.000000
#
# Lx=80, afr=0.25, threshold=0.65, type=plus20, steps 1401->1421
#   数据点: 91
#   Pearson correlation: r = 0.871385, p = 0.000000
#   Spearman correlation: r = 0.942013, p = 0.000000
#
# Lx=80, afr=0.25, threshold=0.65, type=minus_2pct_full, steps 1324->1401
#   数据点: 91
#   Pearson correlation: r = 0.979968, p = 0.000000
#   Spearman correlation: r = 0.996699, p = 0.000000
#
# Lx=80, afr=0.25, threshold=0.65, type=plus_2pct_full, steps 1401->1478
#   数据点: 91
#   Pearson correlation: r = 0.983221, p = 0.000000
#   Spearman correlation: r = 0.995567, p = 0.000000
#
# Lx=80, afr=0.25, threshold=0.8, type=minus20, steps 2628->2648
#   数据点: 91
#   Pearson correlation: r = 0.670847, p = 0.000000
#   Spearman correlation: r = 0.663292, p = 0.000000
#
# Lx=80, afr=0.25, threshold=0.8, type=plus20, steps 2648->2668
#   数据点: 91
#   Pearson correlation: r = 0.834207, p = 0.000000
#   Spearman correlation: r = 0.858088, p = 0.000000
#
# Lx=80, afr=0.25, threshold=0.8, type=minus_2pct_full, steps 2543->2648
#   数据点: 91
#   Pearson correlation: r = 0.981291, p = 0.000000
#   Spearman correlation: r = 0.995548, p = 0.000000
#
# Lx=80, afr=0.25, threshold=0.8, type=plus_2pct_full, steps 2648->2753
#   数据点: 91
#   Pearson correlation: r = 0.984940, p = 0.000000
#   Spearman correlation: r = 0.997396, p = 0.000000
#
# Lx=80, afr=0.25, threshold=0.95, type=minus20, steps 6102->6122
#   数据点: 91
#   Pearson correlation: r = 0.644470, p = 0.000000
#   Spearman correlation: r = 0.701485, p = 0.000000
#
# Lx=80, afr=0.25, threshold=0.95, type=plus20, steps 6122->6142
#   数据点: 91
#   Pearson correlation: r = 0.618117, p = 0.000000
#   Spearman correlation: r = 0.647442, p = 0.000000
#
# Lx=80, afr=0.25, threshold=0.95, type=minus_2pct_full, steps 5947->6122
#   数据点: 91
#   Pearson correlation: r = 0.982747, p = 0.000000
#   Spearman correlation: r = 0.998523, p = 0.000000
#
# Lx=80, afr=0.25, threshold=0.95, type=plus_2pct_full, steps 6122->6297
#   数据点: 91
#   Pearson correlation: r = 0.985487, p = 0.000000
#   Spearman correlation: r = 0.998164, p = 0.000000
#
# Lx=80, afr=0.4, threshold=0.65, type=minus20, steps 856->876
#   数据点: 91
#   Pearson correlation: r = 0.971361, p = 0.000000
#   Spearman correlation: r = 0.983528, p = 0.000000
#
# Lx=80, afr=0.4, threshold=0.65, type=plus20, steps 876->896
#   数据点: 91
#   Pearson correlation: r = 0.954820, p = 0.000000
#   Spearman correlation: r = 0.970278, p = 0.000000
#
# Lx=80, afr=0.4, threshold=0.65, type=minus_2pct_full, steps 828->876
#   数据点: 91
#   Pearson correlation: r = 0.980189, p = 0.000000
#   Spearman correlation: r = 0.997093, p = 0.000000
#
# Lx=80, afr=0.4, threshold=0.65, type=plus_2pct_full, steps 876->924
#   数据点: 91
#   Pearson correlation: r = 0.983186, p = 0.000000
#   Spearman correlation: r = 0.995559, p = 0.000000
#
# Lx=80, afr=0.4, threshold=0.8, type=minus20, steps 1635->1655
#   数据点: 91
#   Pearson correlation: r = 0.881582, p = 0.000000
#   Spearman correlation: r = 0.946389, p = 0.000000
#
# Lx=80, afr=0.4, threshold=0.8, type=plus20, steps 1655->1675
#   数据点: 91
#   Pearson correlation: r = 0.909085, p = 0.000000
#   Spearman correlation: r = 0.973724, p = 0.000000
#
# Lx=80, afr=0.4, threshold=0.8, type=minus_2pct_full, steps 1589->1655
#   数据点: 91
#   Pearson correlation: r = 0.980123, p = 0.000000
#   Spearman correlation: r = 0.994918, p = 0.000000
#
# Lx=80, afr=0.4, threshold=0.8, type=plus_2pct_full, steps 1655->1721
#   数据点: 91
#   Pearson correlation: r = 0.984844, p = 0.000000
#   Spearman correlation: r = 0.997583, p = 0.000000
#
# Lx=80, afr=0.4, threshold=0.95, type=minus20, steps 3806->3826
#   数据点: 91
#   Pearson correlation: r = 0.850253, p = 0.000000
#   Spearman correlation: r = 0.916657, p = 0.000000
#
# Lx=80, afr=0.4, threshold=0.95, type=plus20, steps 3826->3846
#   数据点: 91
#   Pearson correlation: r = 0.868901, p = 0.000000
#   Spearman correlation: r = 0.915073, p = 0.000000
#
# Lx=80, afr=0.4, threshold=0.95, type=minus_2pct_full, steps 3717->3826
#   数据点: 91
#   Pearson correlation: r = 0.983198, p = 0.000000
#   Spearman correlation: r = 0.998184, p = 0.000000
#
# Lx=80, afr=0.4, threshold=0.95, type=plus_2pct_full, steps 3826->3935
#   数据点: 91
#   Pearson correlation: r = 0.985507, p = 0.000000
#   Spearman correlation: r = 0.998682, p = 0.000000
#      Lx  Ly  afr  threshold        pair_type  step_start  step_end  points  \
# 0    40  40  0.1       0.65          minus20         797       817      91
# 1    40  40  0.1       0.65           plus20         817       837      91
# 2    40  40  0.1       0.65  minus_2pct_full         770       817      91
# 3    40  40  0.1       0.65   plus_2pct_full         817       864      91
# 4    40  40  0.1       0.80          minus20        1489      1509      91
# ..   ..  ..  ...        ...              ...         ...       ...     ...
# 103  80  80  0.4       0.80   plus_2pct_full        1655      1721      91
# 104  80  80  0.4       0.95          minus20        3806      3826      91
# 105  80  80  0.4       0.95           plus20        3826      3846      91
# 106  80  80  0.4       0.95  minus_2pct_full        3717      3826      91
# 107  80  80  0.4       0.95   plus_2pct_full        3826      3935      91
#
#      pearson_r     pearson_p  spearman_r     spearman_p
# 0     0.954162  2.080123e-48    0.979419   1.203501e-63
# 1     0.967447  6.741734e-55    0.982513   9.139035e-67
# 2     0.980067  2.934563e-64    0.995237   8.779991e-92
# 3     0.982069  2.757007e-66    0.996898  4.718181e-100
# 4     0.898512  1.400040e-33    0.953639   3.409593e-48
# ..         ...           ...         ...            ...
# 103   0.984844  1.649241e-69    0.997583  7.210345e-105
# 104   0.850253  1.548584e-26    0.916657   3.271396e-37
# 105   0.868901  6.372635e-29    0.915073   7.303461e-37
# 106   0.983198  1.564190e-67    0.998184  2.153662e-110
# 107   0.985507  2.284485e-70    0.998682  1.400840e-116
#
# [108 rows x 12 columns]

# %%
pairs_csv_path = os.path.join(output_dir, 'sensitive_analysis_pair_correlations.csv')
results_df.to_csv(pairs_csv_path, index=False)
pairs_csv_path
# Out:
# '/Users/yanyu/Desktop/课题组文章/金晓强老师/AS审稿意见/20251102代码/sensitive_analysis/sensitive_analysis_pair_correlations.csv'
